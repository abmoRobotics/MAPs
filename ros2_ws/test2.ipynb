# %%
#api_key = 'apk-14166daf4872c6537ffc7e1b30afacdfc519606b7eefd932c5ad4ab5d9693f480b1a254e31ff6781937a14acc1fa4e7410d0460299a4ec3d2681fe801f79f1f81912b3826ca0cfe0c596eeb683ec32eb'
api_key = 'apk-110d39e19561e2e1538f8cb18288c7543ccfbd5f6d2881f2708c64401d0f620a302f360f2123e2b9f867f56a7c5c4479a5d07c540b32d77172c5f572d8488192878aa2be3e15dd73407656a9a2d7dbf5'
from rxn4chemistry import RXN4ChemistryWrapper

import time

rxn4chemistry_wrapper = RXN4ChemistryWrapper(api_key=api_key)
#rxn4chemistry_wrapper.list_all_projects()
#rxn4chemistry_wrapper.set_project('5f9b3e2a0c3e4f0001d8e4e4')
#print(rxn4chemistry_wrapper.list_all_projects()['response']['payload']['content'][0]['name'])
projects = rxn4chemistry_wrapper.list_all_projects()['response']['payload']['content']
time.sleep(1)
for project in projects:
    if project['name'] == 'MAPs':
        rxn4chemistry_wrapper.set_project(project['id'])
    print(project['name'])

print(rxn4chemistry_wrapper.project_id)

time.sleep(1)
response = rxn4chemistry_wrapper.predict_automatic_retrosynthesis(
    'CCO'
)
# Out:
# MAPs
# 64524729008398001f460059

# %%
results = rxn4chemistry_wrapper.get_predict_automatic_retrosynthesis_results(
    response['prediction_id']
)
print(results)
# Out:
# {'retrosynthetic_paths': [], 'status': 'NEW', 'response': {'payload': {'id': '64524d28008398001f465cc8', 'metadata': {}, 'embed': {}, 'computedFields': {}, 'createdOn': 1683115304753, 'createdBy': 'e0964738-1b2b-43ea-99f8-277b9ba99e07', 'modifiedOn': 1683115308324, 'modifiedBy': 'system', 'projectId': '64524729008398001f460059', 'project': {'createdOn': 1683113769268, 'createdBy': 'e0964738-1b2b-43ea-99f8-277b9ba99e07', 'modifiedOn': 1683113769268, 'modifiedBy': 'e0964738-1b2b-43ea-99f8-277b9ba99e07', 'name': 'MAPs', 'description': None, 'visibility': None, 'collectionDB': '', 'id': '64524729008398001f460059'}, 'status': 'NEW', 'errorMessage': 'Internal Server Error', 'task': {'finished_time': 0.0, 'metaData': {}, 'queued_time': None, 'started_time': 0.0, 'status': 'WAITING', 'expected_start': 0.0, 'queue_position': 0, 'task_id': '071f0a5b-ff3a-4aaf-8dd2-6f3531207168', 'retrieval_time': 0.0, 'retry': 0, 'counters': {'backward_prediction': 0, 'forward_prediction': 0}}, 'molecules': [], 'sequences': [], 'sequencesIds': None, 'legend': [{'color': '#002d9c', 'label': 'Common molecule available by default'}, {'color': '#0f62fe', 'label': 'Molecule available using a model-specific database'}, {'color': '#28a30d', 'label': 'Molecule commercially available on eMolecules.com'}, {'color': '#3ddbd9', 'label': 'Molecule commercially available from a database'}, {'color': '#ce4e04', 'label': 'Not able to find a synthetic path'}, {'color': '#f1c21b', 'label': 'Molecule from file'}], 'wizardParameters': None, 'siblings': [], 'metaData': {'max_steps': 3, 'steps': 0}, 'isInteractive': False, 'name': 'MAPs_20230503_12:01:44.751', 'productMolecule': {'id': '5eb27ace759cc0000174d4fb', 'metadata': {}, 'embed': {}, 'computedFields': {}, 'createdOn': 1588755150143, 'createdBy': 'system', 'modifiedOn': 1656939105231, 'modifiedBy': '99f7928e-5992-484e-a0dc-9638a788ab47', 'smiles': 'CCO', 'reactionId': None, 'projectId': '5d8a21a0e5d96c000118fd3b', 'retrosynthesisId': '5eb27aaa759cc0000174d3cf', 'type': 'RETROSYNTHESIS', 'moleculeImage': '<?xml version=\'1.0\' encoding=\'UTF-8\'?>\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\n<svg version=\'1.2\' xmlns=\'http://www.w3.org/2000/svg\' xmlns:xlink=\'http://www.w3.org/1999/xlink\' width=\'8.13mm\' height=\'9.84mm\' viewBox=\'0 0 8.13 9.84\'>\n  <desc>Generated by the Chemistry Development Kit (http://github.com/cdk)</desc>\n  <g stroke-linecap=\'round\' stroke-linejoin=\'round\' stroke=\'#000000\' stroke-width=\'.21\' fill=\'#FF0D0D\'>\n    <rect x=\'.0\' y=\'.0\' width=\'9.0\' height=\'10.0\' fill=\'#FFFFFF\' stroke=\'none\'/>\n    <g id=\'mol1\' class=\'mol\'>\n      <line id=\'mol1bnd1\' class=\'bond\' x1=\'.7\' y1=\'9.14\' x2=\'5.1\' y2=\'6.6\'/>\n      <line id=\'mol1bnd2\' class=\'bond\' x1=\'5.1\' y1=\'6.6\' x2=\'5.1\' y2=\'2.9\'/>\n      <g id=\'mol1atm3\' class=\'atom\'>\n        <path d=\'M5.1 .76q-.27 .0 -.43 .2q-.16 .2 -.16 .55q.0 .35 .16 .55q.16 .2 .43 .2q.27 .0 .43 -.2q.16 -.2 .16 -.55q.0 -.35 -.16 -.55q-.16 -.2 -.43 -.2zM5.1 .56q.39 .0 .62 .26q.23 .26 .23 .7q.0 .44 -.23 .7q-.23 .26 -.62 .26q-.39 .0 -.62 -.26q-.23 -.26 -.23 -.7q.0 -.43 .23 -.7q.23 -.26 .62 -.26z\' stroke=\'none\'/>\n        <path d=\'M6.17 .59h.25v.76h.91v-.76h.25v1.85h-.25v-.88h-.91v.88h-.25v-1.85z\' stroke=\'none\'/>\n      </g>\n    </g>\n  </g>\n</svg>\n', 'moleculeUpdated': True, 'moleculeName': 'ethanol'}, 'predictionStats': None, 'aiModel': '', 'uploadedFile': None, 'isFromFile': False, 'isRenameable': True, 'isFavorite': False, 'isDeletable': True, 'isAiModelDeleted': False, 'isCustom': False}, 'metadata': {'uiMessages': {'errors': [], 'infos': [], 'warnings': []}, 'extendedPagination': {}}}}

# %%
print(results['status'])
print(results['retrosynthetic_paths'])
# Out:
# NEW
# []

# %%
response = rxn4chemistry_wrapper.predict_automatic_retrosynthesis(
    'Brc1c2ccccc2c(Br)c2ccccc12'
)
time.sleep(1)
results = rxn4chemistry_wrapper.get_predict_automatic_retrosynthesis_results(
    response['prediction_id']
)
print(results['status'])
# NOTE: upon 'SUCCESS' you can inspect the predicted retrosynthetic paths.
print(results['retrosynthetic_paths'][0])
